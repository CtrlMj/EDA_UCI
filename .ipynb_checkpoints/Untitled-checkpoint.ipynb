# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.multioutput import MultiOutputRegressor
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.tree import DecisionTreeRegressor
from scipy.stats import norm
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.style.use('bmh')

# %%
student_mat = pd.read_csv('student-mat.csv', sep=";")
student_mat.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   famrel freetime  goout  Dalc  Walc health absences  G1  G2  G3
# 0      4        3      4     1     1      3        6   5   6   6
# 1      5        3      3     1     1      3        4   5   5   6
# 2      4        3      2     2     3      3       10   7   8  10
# 3      3        2      2     1     1      5        2  15  14  15
# 4      4        3      2     1     2      5        4   6  10  10
#
# [5 rows x 33 columns]

# %%
student_mat.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 33 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   school      395 non-null    object
#  1   sex         395 non-null    object
#  2   age         395 non-null    int64
#  3   address     395 non-null    object
#  4   famsize     395 non-null    object
#  5   Pstatus     395 non-null    object
#  6   Medu        395 non-null    int64
#  7   Fedu        395 non-null    int64
#  8   Mjob        395 non-null    object
#  9   Fjob        395 non-null    object
#  10  reason      395 non-null    object
#  11  guardian    395 non-null    object
#  12  traveltime  395 non-null    int64
#  13  studytime   395 non-null    int64
#  14  failures    395 non-null    int64
#  15  schoolsup   395 non-null    object
#  16  famsup      395 non-null    object
#  17  paid        395 non-null    object
#  18  activities  395 non-null    object
# ...

# %% [markdown]
# ###### There are no null values in any columns. So no need to drop or impute anything

# %% [markdown]
# ### We focus on numeric values first:

# %%
student_mat.describe()
# Out:
#               age        Medu        Fedu  traveltime   studytime    failures  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean    16.696203    2.749367    2.521519    1.448101    2.035443    0.334177
# std      1.276043    1.094735    1.088201    0.697505    0.839240    0.743651
# min     15.000000    0.000000    0.000000    1.000000    1.000000    0.000000
# 25%     16.000000    2.000000    2.000000    1.000000    1.000000    0.000000
# 50%     17.000000    3.000000    2.000000    1.000000    2.000000    0.000000
# 75%     18.000000    4.000000    3.000000    2.000000    2.000000    0.000000
# max     22.000000    4.000000    4.000000    4.000000    4.000000    3.000000
#
#            famrel    freetime       goout        Dalc        Walc      health  \
# count  395.000000  395.000000  395.000000  395.000000  395.000000  395.000000
# mean     3.944304    3.235443    3.108861    1.481013    2.291139    3.554430
# ...

# %% [markdown]
# ##### observations:
# - Quiet a few features dont look like they have a standard normal distribution (will maybe dig deeper later)
# - Obviously not many students are day drinkers
# - Mostly enjoy an above average family relation
# - They barely study over 5 hours
# - etc.
#
# ##### we visualize these distributions

# %%
student_mat.hist(figsize=(16, 16))
# Out:
# array([[<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'Medu'}>,
#         <AxesSubplot:title={'center':'Fedu'}>,
#         <AxesSubplot:title={'center':'traveltime'}>],
#        [<AxesSubplot:title={'center':'studytime'}>,
#         <AxesSubplot:title={'center':'failures'}>,
#         <AxesSubplot:title={'center':'famrel'}>,
#         <AxesSubplot:title={'center':'freetime'}>],
#        [<AxesSubplot:title={'center':'goout'}>,
#         <AxesSubplot:title={'center':'Dalc'}>,
#         <AxesSubplot:title={'center':'Walc'}>,
#         <AxesSubplot:title={'center':'health'}>],
#        [<AxesSubplot:title={'center':'absences'}>,
#         <AxesSubplot:title={'center':'G1'}>,
#         <AxesSubplot:title={'center':'G2'}>,
#         <AxesSubplot:title={'center':'G3'}>]], dtype=object)

# %% [markdown]
# ###### Observations
# - People with over 30 absences ought to be outliers? will look further
# - Dalc resembles a poisson distribution; people with too many absances drink a lot?
# - The past two follow failures distribution
# - Almost 40 people got zero on final?! Hope is to find whats common between them
# - Do free time and go out say the same thing?
#
# ###### Next we watch final score with respect to each variable

# %%
for i in range(0, 16, 5):
    sns.pairplot(data=student_mat, x_vars=student_mat.select_dtypes(exclude='object').columns[i:i+5], y_vars=['G3'], diag_kind=None)

# %% [markdown]
# ##### Observations
# - Ok, elephant in the room: These numerical features are not great predictors of whats going on. at least not individually.
# seems as if these are also categorical features; Decision tree regression is serious candidate.
# - Why are there people with highest study time who got zero on final?
# - Alcohol consumption significantly impacts final score
# - Again, why are there people with zero absence who also got zero?
#
# ###### I like to watch the distribution with respect to G3 for a few columns

# %%
fig, axs = plt.subplots(2, 3, figsize=(12, 6))
axs = axs.ravel()
sns.violinplot(x='age', y='G3', data=student_mat, ax=axs[0])
sns.violinplot(x='traveltime', y='G3', data=student_mat, ax=axs[1])
sns.violinplot(x='health', y='G3', data=student_mat, ax=axs[2])
sns.violinplot(x='famrel', y='G3', data=student_mat, ax=axs[3])
sns.violinplot(x='Fedu', y='G3', data=student_mat, ax=axs[4])
sns.violinplot(x='Medu', y='G3', data=student_mat, ax=axs[5])
plt.tight_layout()

# %% [markdown]
# ##### Observations
# - Will put this to test but looks like travel time does not have a huge impace. Except for when travel time is very short.
# - Health could also be reduced to three splits (bad, middle, great)?
#
# ##### Specifically graph below illustrates the health situation (purple plots)

# %%
student_mat.groupby('health')[['G1', 'G2', 'G3']].mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='health'>

# %% [markdown]
# #### Time to unveil correlations

# %%
sns.heatmap(student_mat.drop(['G1', 'G2'], axis=1).corr(), annot=True)
plt.gcf().set_size_inches(12, 8)

# %% [markdown]
# ##### Observations:
# - Mother's education helps. Followed by father's education. Can be replaced with one feature?
# - Older students are less likely to do great
# - Strangely enough, health has negative effect while absence almost helps :/
# - We can probably compose one feature from goout, Dalc and Walc.
# - Some features don't seem to have direct correlation with the final score but affect other features that help/hurt the fincal score. Absence for example increases alcohol consumption, which reduces the study time.
# - family relation looks irrelevant overall
# - age has a negative impact. But there is a bunch of 20 year olds who do pretty good. Will inspect them more closely.

# %%
sns.boxplot(x='absences', y='G3', data=student_mat)
plt.gcf().set_size_inches(12, 8)

# %% [markdown]
# ##### Observations:
# - Students with zero absence who score 0 were a concern. Apparently, they are not outliers and there is quiet a few of them (student_mat.query('absences == 0' and 'G3 == 0').shape[0] = 40).
# - My guess is other side of spectrum contains outliers. See below:

# %%
sns.boxplot(x = student_mat['absences'])
sns.pairplot(x_vars='health', y_vars='absences', data=student_mat, diag_kind=None)

# %% [markdown]
# #### There you go. Some students have too many absences for no good reason (not even health). Entries with more than 24 absences will be removed

# %%
sns.boxplot(x=student_mat['age'])
print(student_mat.loc[student_mat['age'] > 19, :].shape)
# Out:
# (5, 33)

# %% [markdown]
# #### There is only 5 students with age 20 or above. And they ruin the downward trend in the violin plot. Outliers!
# ##### Now I like to find out whats up with guys who studied the most but got zero

# %%
student_mat.query("G3==0 and studytime==4")[['studytime', 'G3', 'absences']]
# Out:
#      studytime  G3  absences
# 140          4   0         0
# 259          4   0         0
# 334          4   0         0

# %% [markdown]
# #### They had no absences, they studied the most, yet still failed disgracefully. I call outliers

# %%
df = student_mat.drop(student_mat[(student_mat['G3'] == 0) & (student_mat['studytime']==4)].index, axis=0)
df = df.drop(df[df['age'] > 19].index, axis=0)
df.shape
# Out:
# (387, 33)

# %% [markdown]
# ##### Moving on to categorical columns:

# %%
df.describe(include=['object'])
# Out:
#        school  sex address famsize Pstatus   Mjob   Fjob  reason guardian  \
# count     387  387     387     387     387    387    387     387      387
# unique      2    2       2       2       2      5      5       4        3
# top        GP    F       U     GT3       T  other  other  course   mother
# freq      344  205     301     275     348    140    213     138      271
#
#        schoolsup famsup paid activities nursery higher internet romantic
# count        387    387  387        387     387    387      387      387
# unique         2      2    2          2       2      2        2        2
# top           no    yes   no        yes     yes    yes      yes       no
# freq         337    239  209        198     309    368      325      258

# %% [markdown]
# #### Another thing I like to know is the distribution in these features:

# %%
fig, axs = plt.subplots(6, 3, figsize=(15, 20))
axs = axs.ravel()
cols = df.select_dtypes(include='object').columns
for i in range(17):
    sns.countplot(x=cols[i], data=df, ax=axs[i])

# %%
# grid = sns.PairGrid(data=pd.concat([df.select_dtypes(include='object'), df['G3']], axis=1), 
#                     size=3, diag_sharey=False, vars=[col for col in df.select_dtypes(include='object').columns], hue='G3')
# grid.map_upper(plt.scatter, alpha=0.2)
# #grid.map_diag(sns.kdeplot)
# grid.map_lower(sns.kdeplot, cmap=plt.cm.OrRd_r)

# %%
fig, axs = plt.subplots(6, 3, figsize=(15, 20))
axs = axs.ravel()
cols = df.select_dtypes(include='object').columns
for i in range(17):
    sns.boxplot(x=cols[i], y='G3', data=df, ax=axs[i])
plt.tight_layout()

# %% [markdown]
# #### Aside from zero final score points, not much can be read from these figures. For example, naturally people who want to pursue higher education, work harder and receive better marks. One thing that might help is replacing categorical values with ordered numerics. For example, for 'higher', we can have 4 and 1 for yes and no respectively. Sort of giving more chance of having better final mark to the corresponding group.

# %%
pd.crosstab(df['Mjob'], df['Fjob'], values=df['G3'], aggfunc='mean')
# Out:
# Fjob        at_home  health      other   services    teacher
# Mjob
# at_home   12.285714   11.50   9.156250   8.800000   3.000000
# health          NaN   13.50  11.375000  12.400000  11.000000
# other      9.200000   12.00   9.825243   9.500000  11.333333
# services   8.166667   10.25  11.195122  11.150000  13.125000
# teacher   11.000000   10.00  10.761905  10.888889  13.083333

# %%
pd.crosstab(df['Mjob'], df['Medu'])
# Out:
# Medu      0   1   2   3   4
# Mjob
# at_home   2  25  21   8   2
# health    0   1   2   5  25
# other     1  27  47  43  22
# services  0   5  30  38  26
# teacher   0   0   0   3  54

# %% [markdown]
# ##### Mother's job and education are supposed to be correlated and they are to some extent. But people with level 4 education are dispersed in all jobs. Same will go for Fathers

# %% [markdown]
# #### Cannot build a correlation matrix for categorical values. But we can watch supposedly related columns in factorplots:

# %%
sns.factorplot(x='Fjob', y='G3', hue='paid',data=df, col='Mjob')
plt.gcf().set_size_inches(20, 8)
plt.tight_layout()
# Out:
# /home/mao919/anaconda3/envs/py37-start/lib/python3.7/site-packages/seaborn/categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# #### My speculation was that as long as exra classes are paid for, the final score will be better regardless of father's or mother's occupation. Apparently this not the case. For example if one of the parents is a teacher, people without paid classes usually do better since they probably learn far better under their parents instructions
#
#
# ##### Isn't this the case that people with rural address would go to one school and people in urban areas go to another? :

# %%
print(pd.crosstab(df['address'], df['school'], margins=True))
sns.factorplot(x='address', y='G3', hue='school', data=df)
# Out:
# school    GP  MS  All
# address
# R         62  24   86
# U        282  19  301
# All      344  43  387
# /home/mao919/anaconda3/envs/py37-start/lib/python3.7/site-packages/seaborn/categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %% [markdown]
# #### Not the case. Regardless of urban or rural, people go to both schools

# %% [markdown]
# ##### I am interested to see if I can estimate the final score itself (not what class it falls into). Therefore this is a regression problem and when the final output is a number, I don't think any of these features can be ignored.
#
# ##### transforming categorical features to numeric values:

# %%
le = LabelEncoder()
df['school'] = le.fit_transform(df['school'])
df['sex'] = le.fit_transform(df['sex'])
df['address'] = le.fit_transform(df['address'])
df['famsize'] = le.fit_transform(df['famsize'])
df['Pstatus'] = le.fit_transform(df['Pstatus'])
df['famsup'] = le.fit_transform(df['famsup'])
df['schoolsup'] = le.fit_transform(df['schoolsup'])
df['paid'] = le.fit_transform(df['paid'])
df['activities'] = le.fit_transform(df['activities'])
df['nursery'] = le.fit_transform(df['nursery'])
df['higher'] = le.fit_transform(df['higher'])
df['internet'] = le.fit_transform(df['internet'])
df['romantic'] = le.fit_transform(df['romantic'])

# %%
df = student_mat.drop(['G1', 'G2', 'G3'], axis=1)
targets = student_mat[['G1', 'G2', 'G3']]
df.head()
# Out:
#   school sex  age address famsize Pstatus  Medu  Fedu     Mjob      Fjob  ...  \
# 0     GP   F   18       U     GT3       A     4     4  at_home   teacher  ...
# 1     GP   F   17       U     GT3       T     1     1  at_home     other  ...
# 2     GP   F   15       U     LE3       T     1     1  at_home     other  ...
# 3     GP   F   15       U     GT3       T     4     2   health  services  ...
# 4     GP   F   16       U     GT3       T     3     3    other     other  ...
#
#   higher internet  romantic  famrel  freetime goout Dalc Walc health absences
# 0    yes       no        no       4         3     4    1    1      3        6
# 1    yes      yes        no       5         3     3    1    1      3        4
# 2    yes      yes        no       4         3     2    2    3      3       10
# 3    yes      yes       yes       3         2     2    1    1      5        2
# 4    yes       no        no       4         3     2    1    2      5        4
#
# [5 rows x 30 columns]

# %%
le = LabelEncoder()
df['school'] = le.fit_transform(df['school'])
df['sex'] = le.fit_transform(df['sex'])
df['address'] = le.fit_transform(df['address'])
df['famsize'] = le.fit_transform(df['famsize'])
df['Pstatus'] = le.fit_transform(df['Pstatus'])
df['famsup'] = le.fit_transform(df['famsup'])
df['schoolsup'] = le.fit_transform(df['schoolsup'])
df['paid'] = le.fit_transform(df['paid'])
df['activities'] = le.fit_transform(df['activities'])
df['nursery'] = le.fit_transform(df['nursery'])
df['higher'] = le.fit_transform(df['higher'])
df['internet'] = le.fit_transform(df['internet'])
df['romantic'] = le.fit_transform(df['romantic'])
df = pd.get_dummies(df)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 387 entries, 0 to 394
# Data columns (total 46 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   school             387 non-null    int64
#  1   sex                387 non-null    int64
#  2   age                387 non-null    int64
#  3   address            387 non-null    int64
#  4   famsize            387 non-null    int64
#  5   Pstatus            387 non-null    int64
#  6   Medu               387 non-null    int64
#  7   Fedu               387 non-null    int64
#  8   traveltime         387 non-null    int64
#  9   studytime          387 non-null    int64
#  10  failures           387 non-null    int64
#  11  schoolsup          387 non-null    int64
#  12  famsup             387 non-null    int64
#  13  paid               387 non-null    int64
#  14  activities         387 non-null    int64
#  15  nursery            387 non-null    int64
# ...

# %%
tr = DecisionTreeRegressor()
cross_val_score(tr, X=df, y=targets, cv=6)
# Out:
# array([-0.29559174, -0.64021707, -0.29021608, -0.61378585, -2.00533502,
#        -0.93636474])

# %%
df = pd.get_dummies(df, columns=['Mjob', 'Fjob', 'reason', 'guardian'])
mlr = MultiOutputRegressor(LinearRegression())
cross_val_score(mlr, X=df, y=targets, cv=6)
# Out:
# array([ 0.04249525,  0.17149402,  0.12596032, -0.15547152, -0.24080562,
#        -0.01595239])

# %%
cross_val_score(tr, X=df, y=targets, cv=6)
# Out:
# array([-1.32021125, -0.39884094, -0.51822293, -1.00577065, -1.54074402,
#        -1.17368097])

# %%
fig, axs = plt.subplots(1, 3, figsize=(12, 3))
sns.distplot(student_mat['G1'], color='g', bins=20, hist_kws={'alpha': 0.4}, ax=axs[0], fit=norm)
sns.distplot(student_mat['G2'], color='b', bins=20, hist_kws={'alpha': 0.4}, ax=axs[1], fit=norm)
sns.distplot(student_mat['G3'], color='r', bins=20, hist_kws={'alpha': 0.4}, ax=axs[2], fit=norm)
# Out:
# /home/mao919/anaconda3/envs/py37-start/lib/python3.7/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /home/mao919/anaconda3/envs/py37-start/lib/python3.7/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
student_mat.groupby(by='school')[['G1', 'G2', 'G3']].mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='school'>

# %%
student_mat.groupby(by='sex')[['G1', 'G2', 'G3']].mean().plot.bar()
# Out:
# <AxesSubplot:xlabel='sex'>

# %%
len(student_mat.columns[student_mat.nunique() <= 5])
# Out:
# 28

# %%
fig, axs = plt.subplots(5, 6, figsize=(18, 14))
axs = axs.ravel()
smalcol = student_mat.columns[student_mat.nunique() <= 5]
for i in range(0, 28):
    student_mat.groupby([smalcol[i]])[['G1', 'G2', 'G3']].mean().plot.bar(ax=axs[i], legend=None)

plt.tight_layout()

# %%
sns.factorplot('school', 'G3', hue='address', data=student_mat)
# Out:
# /home/mao919/anaconda3/envs/py37-start/lib/python3.7/site-packages/seaborn/categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /home/mao919/anaconda3/envs/py37-start/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.factorplot(x='Mjob', y='G3', hue='address', data=student_mat, col='sex')
sns.factorplot(x='Fjob', y='G3', hue='address', data=student_mat)
# Out:
# /home/mao919/anaconda3/envs/py37-start/lib/python3.7/site-packages/seaborn/categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /home/mao919/anaconda3/envs/py37-start/lib/python3.7/site-packages/seaborn/categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot('famsup', 'G3', hue='Mjob', data=student_mat)
sns.factorplot('famsup', 'G3', hue='Fjob', data=student_mat)
# Out:
# /home/mao919/anaconda3/envs/py37-start/lib/python3.7/site-packages/seaborn/categorical.py:3704: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)
# /home/mao919/anaconda3/envs/py37-start/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %%
sns.violinplot('age', 'G2', hue='sex', data=student_mat, split=True)
# Out:
# /home/mao919/anaconda3/envs/py37-start/lib/python3.7/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# <AxesSubplot:xlabel='age', ylabel='G2'>
